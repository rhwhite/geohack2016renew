# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt



# %matplotlib inline

# %%
df = pd.read_csv('../data/trainingData.csv')

# %%
wind = 0
solar = 1
geotherm = 2

# %%
df.head()
# Out:
#   system:index     aspect  elevation  nameindex     slope       srad  \
# 0    1_1_697_0  199.10187        135        1.0  3.920016  163.26500
# 1    1_1_270_0   -0.00000        456        1.0  2.780288  161.35290
# 2   1_1_1148_0  180.00000         97        1.0  0.927410  157.52954
# 3     1_1_95_0   -0.00000        270        1.0  3.704792  156.35289
# 4    1_1_988_0  242.02467         97        1.0  5.910566  156.09215
#
#          vs  .geo
# 0  5.886150   NaN
# 1  4.057361   NaN
# 2  4.345870   NaN
# 3  5.199133   NaN
# 4  3.917390   NaN

# %%
df_wind = df[df['nameindex'] == 0]
df_solar = df[df['nameindex'] == 1]
df_geotherm = df[df['nameindex'] == 2]

# %%
df_solar['srad'].hist(bins=30)

# %%
df_wind['srad'].hist(bins=30)

# %%
df_solar['vs'].hist(bins=30, range=(0,7))

# %%
df_wind['vs'].hist(bins=30, range=(0,7))

# %%
df_solar['aspect'].var()
df_solar['aspect'].median()
# Out:
# 160.44742

# %%
df_wind['aspect'].var()
df_wind['aspect'].median()
# Out:
# 166.68242

# %%
plt.plot(df_solar['srad'], df_solar['vs'], 'o')

# %%
plt.plot(df_wind['srad'], df_wind['vs'], 'o')
